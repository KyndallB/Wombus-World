# %% [markdown]
# ## Data Preparation

# %%
#Dependencies...
import pandas as pd
import numpy as np
import random as rd
import requests
import json
import math
import os

# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

from scipy.stats import shapiro 
from scipy.stats import lognorm

# %%
#Create data file paths:
recruits_path = "../resources/wombi_candidates.csv"
employees_path = "../resources/wombi_employees.csv"

#Read the file paths:
rec = pd.read_csv(recruits_path)
emp = pd.read_csv(employees_path)

# %%
rec.count()
# Out:
# wombus_id                          449
# birth_continent                    423
# gender                             448
# age                                442
# college_degree                     399
# problem_solving_skill              433
# technology_skill                   421
# english_skill                      368
# most_recent_income                 438
# total_jobs                         313
# shirt_color_preference             445
# customer_exp_preference            396
# work_env_preference                445
# personal_growth_preference         429
# honest_communication_preference    433
# community_service_preference       446
# remote_work_preference             417
# industry_preference                444
# dtype: int64

# %%
emp.count()
# Out:
# wombus_id                          233936
# birth_continent                    222243
# gender                             231593
# age                                231599
# college_degree                     205860
# problem_solving_skill              224577
# technology_skill                   212869
# english_skill                      194172
# most_recent_income                 226915
# total_jobs                         156725
# shirt_color_preference             231596
# customer_exp_preference            205863
# work_env_preference                231596
# personal_growth_preference         226924
# honest_communication_preference    226920
# community_service_preference       229251
# remote_work_preference             215217
# industry_preference                231597
# score                              233936
# dtype: int64

# %%
#Evaluating the data's distribution...
#Draw a random seed and make the test reproducible:
np.random.seed(100)
#Generate a dataset that contains 1000 log-normal distributed values:
lognorm_set = lognorm.rvs(s=.5, scale=math.exp(1), size=1000)
#Perform a Shapiro-Wilk test for normality:
shapiro(lognorm_set)
# Out:
# ShapiroResult(statistic=0.8157703280448914, pvalue=2.5959249901574765e-32)

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Recruits/Candidates

# %%
#Converting recruits' most recent income to float...
rec["most_recent_income"] = [float(str(i).replace(",", "")) for i in rec["most_recent_income"]]

rec.head()
# Out:
#    wombus_id birth_continent  gender   age  college_degree  \
# 0       1105             NaN  Female   NaN             0.0
# 1       1106   North America  Female  52.0             1.0
# 2       1107   North America    Male  32.0             0.0
# 3       1108          Africa    Male  49.0             0.0
# 4       1109   North America    Male  47.0             0.0
#
#    problem_solving_skill  technology_skill  english_skill  most_recent_income  \
# 0               8.400397         23.348271       9.105426             77367.0
# 1               7.787927         24.799825       9.095713             78979.0
# 2              23.005739         25.484927       8.967305             38932.0
# 3              15.565866               NaN       5.914387             58511.0
# 4              12.784366         30.619283       8.751296             65831.0
#
#    total_jobs shirt_color_preference customer_exp_preference  \
# 0         5.0                 Purple       Strongly Disagree
# 1         4.0                   Blue                 Neutral
# 2         NaN                   Blue       Strongly Disagree
# 3         NaN                 Purple                Disagree
# 4         NaN                 Purple       Strongly Disagree
#
#   work_env_preference personal_growth_preference  \
# 0      Strongly Agree                      Agree
# 1   Strongly Disagree                   Disagree
# 2            Disagree                      Agree
# 3      Strongly Agree                      Agree
# 4            Disagree                    Neutral
#
#   honest_communication_preference community_service_preference  \
# 0                         Neutral               Strongly Agree
# 1                  Strongly Agree               Strongly Agree
# 2                           Agree                      Neutral
# 3                         Neutral               Strongly Agree
# 4                  Strongly Agree               Strongly Agree
#
#   remote_work_preference industry_preference
# 0                 Hybrid    Higher Education
# 1                 Hybrid             Finance
# 2                On-Site             Finance
# 3                    NaN                Tech
# 4                On-Site    Renewable Energy

# %%
#Finding the median values for some of the recruit variables to impute data:
age =rec['age'].median()
income = rec['most_recent_income'].median()
tech_skill = rec['technology_skill'].median()
eng_skill = rec['english_skill'].median()
solving_skill = rec['problem_solving_skill'].median()

print("The median value for age is " + str(age) + " years old.")
print("The median value for most recent income is " + str(income) + " WombiCoin.")
print("The median value for technology skill is " + str(tech_skill) + ".")
print("The median value for english skill is " + str(eng_skill) + ".")
print("The median value for problem solving skill is " + str(solving_skill) + ".")
# Out:
# The median value for age is 44.0 years old.
# The median value for most recent income is 61080.5 WombiCoin.
# The median value for technology skill is 26.03470274.
# The median value for english skill is 8.142138163.
# The median value for problem solving skill is 14.51715814.

# %%
#Finding the mode for some of the recruit variables to impute data...

import statistics
from statistics import mode

birth =rec['birth_continent'].mode()
gender = rec['gender'].mode()
work_env = rec['work_env_preference'].mode()
growth = rec['personal_growth_preference'].mode()
comm = rec['honest_communication_preference'].mode()
service = rec['community_service_preference'].mode()
remote = rec['remote_work_preference'].mode()
industry = rec['industry_preference'].mode()
shirt = rec['shirt_color_preference'].mode()

print("The mode for birth continent is " + birth + ".")
print("The mode for gender is " + gender + ".")
print("The mode for work environment is " + work_env + ".")
print("The mode for personal growth experience is " + growth + ".")
print("The mode for communication preference is " + comm + ".")
print("The mode for community service preference is " + service + ".")
print("The mode for remote work preference is " + remote + " work.")
print("The mode for industry preference is the " + industry + ".")
print("The mode for shirt color preference is a " + shirt + " shirt.")
# Out:
# 0    The mode for birth continent is North America.
# Name: birth_continent, dtype: object
# 0    The mode for gender is Female.
# Name: gender, dtype: object
# 0    The mode for work environment is Strongly Agree.
# Name: work_env_preference, dtype: object
# 0    The mode for personal growth experience is Agree.
# Name: personal_growth_preference, dtype: object
# 0    The mode for communication preference is Neutral.
# Name: honest_communication_preference, dtype: object
# 0    The mode for community service preference is S...
# Name: community_service_preference, dtype: object
# 0    The mode for remote work preference is Hybrid ...
# Name: remote_work_preference, dtype: object
# 0    The mode for industry preference is the Tech.
# Name: industry_preference, dtype: object
# 0    The mode for shirt color preference is a Purpl...
# Name: shirt_color_preference, dtype: object

# %%
#Imputing missing values for recruit data:
rec["birth_continent"].fillna("North America", inplace = True)
rec["gender"].fillna("Female", inplace = True)
rec["age"].fillna(44.0, inplace = True)
rec["college_degree"].fillna("Unsure", inplace = True)
rec["most_recent_income"].fillna(61080.5, inplace = True)
rec["total_jobs"].fillna("Unsure", inplace = True)
rec["technology_skill"].fillna(26.03470274, inplace = True)
rec["english_skill"].fillna(8.142138163, inplace = True)
rec["problem_solving_skill"].fillna(14.51715814, inplace = True)
rec["customer_exp_preference"].fillna("Unsure", inplace = True)
rec["work_env_preference"].fillna("Strongly Agree", inplace = True)
rec["personal_growth_preference"].fillna("Agree", inplace = True)
rec["shirt_color_preference"].fillna("Purple", inplace = True)
rec["honest_communication_preference"].fillna("Neutral", inplace = True)
rec["community_service_preference"].fillna("Strongly Agree", inplace = True)
rec["remote_work_preference"].fillna("Hybrid", inplace = True)
rec["industry_preference"].fillna("Tech", inplace = True)

# %%
#Checking the manipulated dataframe:
rec.head(n=20)
# Out:
#     wombus_id birth_continent  gender   age college_degree  \
# 0        1105   North America  Female  44.0            0.0
# 1        1106   North America  Female  52.0            1.0
# 2        1107   North America    Male  32.0            0.0
# 3        1108          Africa    Male  49.0            0.0
# 4        1109   North America    Male  47.0            0.0
# 5        1110   North America    Male  41.0         Unsure
# 6        1111          Africa  Female  54.0            0.0
# 7        1112   North America    Male  54.0            1.0
# 8        1113            Asia    Male  40.0            0.0
# 9        1114   North America    Male  57.0            0.0
# 10       1115   North America  Female  44.0            0.0
# 11       1116            Asia  Female  52.0            0.0
# 12       1117            Asia    Male  35.0            1.0
# 13       1118   North America  Female  35.0            0.0
# 14       1119            Asia  Female  59.0         Unsure
# 15       1120   North America    Male  53.0            0.0
# 16       1121   North America  Female  41.0            0.0
# 17       1122   North America  Female  37.0            0.0
# 18       1123          Africa    Male  47.0            1.0
# 19       1124          Africa    Male  44.0            0.0
#
#     problem_solving_skill  technology_skill  english_skill  \
# 0                8.400397         23.348271       9.105426
# 1                7.787927         24.799825       9.095713
# 2               23.005739         25.484927       8.967305
# 3               15.565866         26.034703       5.914387
# 4               12.784366         30.619283       8.751296
# 5               23.585086         27.179060       9.042111
# 6               14.478490         27.205718       4.806768
# 7               17.664610         23.039488       6.377980
# 8               14.517158         24.277833       8.142138
# 9               16.822555         29.276798       8.124911
# 10              10.402993         26.459082       8.086716
# 11              19.085699         28.607906       5.213967
# 12              11.933707         24.603729       5.893328
# 13              16.104977         26.034703       9.299056
# 14              15.839601         26.285446       5.964917
# 15              15.642793         16.481228       8.142138
# 16              10.816829         29.967428       8.285217
# 17              14.686460         28.321576       7.870973
# 18              15.016627         25.747350       6.284590
# 19              21.545721         22.811052       6.833564
#
#     most_recent_income total_jobs shirt_color_preference  \
# 0              77367.0        5.0                 Purple
# 1              78979.0        4.0                   Blue
# 2              38932.0     Unsure                   Blue
# 3              58511.0     Unsure                 Purple
# 4              65831.0     Unsure                 Purple
# 5              37408.0        3.0                 Purple
# 6              61372.0        4.0                 Purple
# 7              52988.0        5.0                 Purple
# 8              53792.0     Unsure                 Purple
# 9              61080.5        3.0                 Purple
# 10             72097.0        4.0                   Blue
# 11             49248.0        3.0                   Blue
# 12             68069.0     Unsure                 Purple
# 13             61080.5     Unsure                   Blue
# 14             57791.0        4.0                 Purple
# 15             58308.0        6.0                 Purple
# 16             71008.0        3.0                 Purple
# 17             60825.0        4.0                   Blue
# 18             59956.0     Unsure                   Blue
# 19             42774.0        4.0                 Purple
#
#    customer_exp_preference work_env_preference personal_growth_preference  \
# 0        Strongly Disagree      Strongly Agree                      Agree
# 1                  Neutral   Strongly Disagree                   Disagree
# 2        Strongly Disagree            Disagree                      Agree
# 3                 Disagree      Strongly Agree                      Agree
# 4        Strongly Disagree            Disagree                    Neutral
# 5        Strongly Disagree            Disagree                      Agree
# 6                 Disagree            Disagree                      Agree
# 7           Strongly Agree            Disagree                   Disagree
# 8                    Agree            Disagree                      Agree
# 9                  Neutral      Strongly Agree                      Agree
# 10       Strongly Disagree      Strongly Agree                   Disagree
# 11          Strongly Agree      Strongly Agree                   Disagree
# 12       Strongly Disagree            Disagree                    Neutral
# 13       Strongly Disagree               Agree                   Disagree
# 14          Strongly Agree      Strongly Agree                      Agree
# 15          Strongly Agree               Agree                      Agree
# 16                   Agree             Neutral             Strongly Agree
# 17                  Unsure      Strongly Agree                      Agree
# 18                   Agree      Strongly Agree                      Agree
# 19                 Neutral            Disagree                      Agree
#
#    honest_communication_preference community_service_preference  \
# 0                          Neutral               Strongly Agree
# 1                   Strongly Agree               Strongly Agree
# 2                            Agree                      Neutral
# 3                          Neutral               Strongly Agree
# 4                   Strongly Agree               Strongly Agree
# 5                          Neutral               Strongly Agree
# 6                         Disagree               Strongly Agree
# 7                          Neutral               Strongly Agree
# 8                          Neutral               Strongly Agree
# 9                   Strongly Agree               Strongly Agree
# 10                  Strongly Agree                        Agree
# 11               Strongly Disagree               Strongly Agree
# 12                  Strongly Agree               Strongly Agree
# 13                         Neutral               Strongly Agree
# 14                         Neutral               Strongly Agree
# 15                  Strongly Agree               Strongly Agree
# 16               Strongly Disagree               Strongly Agree
# 17               Strongly Disagree               Strongly Agree
# 18                         Neutral               Strongly Agree
# 19                  Strongly Agree                        Agree
#
#    remote_work_preference industry_preference
# 0                  Hybrid    Higher Education
# 1                  Hybrid             Finance
# 2                 On-Site             Finance
# 3                  Hybrid                Tech
# 4                 On-Site    Renewable Energy
# 5                  Hybrid             Finance
# 6                  Hybrid    Higher Education
# 7                  Hybrid    Higher Education
# 8                  Hybrid                Tech
# 9                  Hybrid    Higher Education
# 10                On-Site             Finance
# 11                 Remote                Tech
# 12                 Hybrid    Renewable Energy
# 13                 Hybrid             Finance
# 14                 Hybrid             Finance
# 15                 Hybrid    Higher Education
# 16                 Hybrid                Tech
# 17                On-Site             Finance
# 18                 Hybrid             Finance
# 19                On-Site             Finance

# %% [markdown]
# ### Employees

# %%
#Converting employees' most recent income to float...
emp["most_recent_income"] = [float(str(i).replace(",", "")) for i in emp["most_recent_income"]]

emp.head()
# Out:
#    wombus_id birth_continent  gender   age  college_degree  \
# 0       1554   North America    Male  51.0             NaN
# 1       1555   North America  Female  48.0             0.0
# 2       1556             NaN  Female  47.0             0.0
# 3       1557   North America    Male  35.0             0.0
# 4       1558            Asia  Female  45.0             0.0
#
#    problem_solving_skill  technology_skill  english_skill  most_recent_income  \
# 0                    NaN         31.522899       8.274305             65213.0
# 1              17.016506         24.785969       9.426865             54693.0
# 2                    NaN         27.225131       5.772313             47381.0
# 3              20.723280         25.528884       8.825814             44939.0
# 4              15.862225         31.854325       4.140779             57731.0
#
#    total_jobs shirt_color_preference customer_exp_preference  \
# 0         NaN                 Purple       Strongly Disagree
# 1         NaN                   Blue       Strongly Disagree
# 2         4.0                 Purple                   Agree
# 3         NaN                   Blue                   Agree
# 4         NaN                   Blue                   Agree
#
#   work_env_preference personal_growth_preference  \
# 0            Disagree                      Agree
# 1      Strongly Agree             Strongly Agree
# 2               Agree                      Agree
# 3                 NaN                      Agree
# 4      Strongly Agree                      Agree
#
#   honest_communication_preference community_service_preference  \
# 0                  Strongly Agree               Strongly Agree
# 1                        Disagree               Strongly Agree
# 2                         Neutral               Strongly Agree
# 3                         Neutral               Strongly Agree
# 4                         Neutral               Strongly Agree
#
#   remote_work_preference industry_preference  score
# 0                 Hybrid    Renewable Energy  61.06
# 1                 Hybrid             Finance  53.20
# 2                On-Site             Finance  70.18
# 3                 Hybrid                Tech  58.37
# 4                 Hybrid             Finance  61.77

# %%
#Finding the median value for some of the employee variables to impute data:
age =emp['age'].median()
income = emp['most_recent_income'].median()
tech_skill = emp['technology_skill'].median()
eng_skill = emp['english_skill'].median()
solving_skill = emp['problem_solving_skill'].median()

print("The median value for age is " + str(age) + " years old.")
print("The median value for most recent income is " + str(income) + " WombiCoin.")
print("The median value for technology skill is " + str(tech_skill) + ".")
print("The median value for english skill is " + str(eng_skill) + ".")
print("The median value for problem solving skill is " + str(solving_skill) + ".")
# Out:
# The median value for age is 45.0 years old.
# The median value for most recent income is 60010.0 WombiCoin.
# The median value for technology skill is 26.3804767.
# The median value for english skill is 7.9319140835.
# The median value for problem solving skill is 14.99398769.

# %%
#Finding the mode for some of the employee variables to impute data:

birth =emp['birth_continent'].mode()
gender = emp['gender'].mode()
work_env = emp['work_env_preference'].mode()
growth = emp['personal_growth_preference'].mode()
comm = emp['honest_communication_preference'].mode()
service = emp['community_service_preference'].mode()
remote = emp['remote_work_preference'].mode()
industry = emp['industry_preference'].mode()
shirt = emp['shirt_color_preference'].mode()

print("The mode for birth continent is " + birth + ".")
print("The mode for gender is " + gender + ".")
print("The mode for work environment is " + work_env + ".")
print("The mode for personal growth experience is " + growth + ".")
print("The mode for communication preference is " + comm + ".")
print("The mode for community service preference is " + service + ".")
print("The mode for remote work preference is " + remote + " work.")
print("The mode for industry preference is the " + industry + ".")
print("The mode for shirt color preference is a " + shirt + " shirt.")
# Out:
# 0    The mode for birth continent is North America.
# Name: birth_continent, dtype: object
# 0    The mode for gender is Female.
# Name: gender, dtype: object
# 0    The mode for work environment is Strongly Agree.
# Name: work_env_preference, dtype: object
# 0    The mode for personal growth experience is Agree.
# Name: personal_growth_preference, dtype: object
# 0    The mode for communication preference is Neutral.
# Name: honest_communication_preference, dtype: object
# 0    The mode for community service preference is S...
# Name: community_service_preference, dtype: object
# 0    The mode for remote work preference is Hybrid ...
# Name: remote_work_preference, dtype: object
# 0    The mode for industry preference is the Tech.
# Name: industry_preference, dtype: object
# 0    The mode for shirt color preference is a Purpl...
# Name: shirt_color_preference, dtype: object

# %%
#Imputing missing values for recruit data:
emp["birth_continent"].fillna("North America", inplace = True)
emp["gender"].fillna("Female", inplace = True)
emp["age"].fillna(45.0, inplace = True)
emp["college_degree"].fillna("Unsure", inplace = True)
emp["most_recent_income"].fillna(60010.0, inplace = True)
emp["total_jobs"].fillna("Unsure", inplace = True)
emp["english_skill"].fillna(7.9319140835, inplace = True)
emp["technology_skill"].fillna(26.3804767, inplace = True)
emp["problem_solving_skill"].fillna(14.99398769, inplace = True)
emp["customer_exp_preference"].fillna("Unsure", inplace = True)
emp["work_env_preference"].fillna("Strongly Agree", inplace = True)
emp["personal_growth_preference"].fillna("Agree", inplace = True)
emp["shirt_color_preference"].fillna("Purple", inplace = True)
emp["honest_communication_preference"].fillna("Neutral", inplace = True)
emp["community_service_preference"].fillna("Strongly Agree", inplace = True)
emp["remote_work_preference"].fillna("Hybrid", inplace = True)
emp["industry_preference"].fillna("Tech", inplace = True)

# %%
#Checking the manipulated dataframe:
emp.head(n=20)
# Out:
#     wombus_id birth_continent  gender   age college_degree  \
# 0        1554   North America    Male  51.0         Unsure
# 1        1555   North America  Female  48.0            0.0
# 2        1556   North America  Female  47.0            0.0
# 3        1557   North America    Male  35.0            0.0
# 4        1558            Asia  Female  45.0            0.0
# 5        1559   North America    Male  55.0            0.0
# 6        1560   North America    Male  47.0            0.0
# 7        1561          Africa    Male  67.0            0.0
# 8        1562   North America    Male  39.0            0.0
# 9        1563   North America  Female  55.0            0.0
# 10       1564            Asia    Male  43.0            0.0
# 11       1565   North America    Male  38.0            0.0
# 12       1566            Asia  Female  66.0            0.0
# 13       1567   North America  Female  36.0            0.0
# 14       1568   North America    Male  36.0            0.0
# 15       1569   North America    Male  46.0         Unsure
# 16       1570   North America    Male  47.0            1.0
# 17       1571   North America    Male  35.0            0.0
# 18       1572   North America    Male  53.0            0.0
# 19       1573   North America    Male  45.0            0.0
#
#     problem_solving_skill  technology_skill  english_skill  \
# 0               14.993988         31.522899       8.274305
# 1               17.016506         24.785969       9.426865
# 2               14.993988         27.225131       5.772313
# 3               20.723280         25.528884       8.825814
# 4               15.862225         31.854325       4.140779
# 5               14.725214         22.168891       9.496525
# 6               10.598648         26.529753       9.386864
# 7               15.010481         25.382305       6.452992
# 8               13.553051         24.696864       9.142987
# 9               21.202096         30.773384       8.406603
# 10              14.170282         25.893922       7.931914
# 11              16.874109         26.380477       7.991040
# 12              10.909621         29.006480       5.934940
# 13              11.885339         30.827703       7.348390
# 14              20.136346         29.285150       8.682890
# 15              11.557641         26.959132       5.297224
# 16               7.868168         30.516568       9.227582
# 17              12.359619         27.315665       9.232941
# 18              15.828847         26.380477       9.519960
# 19              17.137678         27.023645       9.079553
#
#     most_recent_income total_jobs shirt_color_preference  \
# 0              65213.0     Unsure                 Purple
# 1              54693.0     Unsure                   Blue
# 2              47381.0        4.0                 Purple
# 3              44939.0     Unsure                   Blue
# 4              57731.0     Unsure                   Blue
# 5              60723.0        5.0                 Purple
# 6              71583.0        3.0                   Blue
# 7              59972.0        4.0                 Purple
# 8              63808.0        4.0                 Purple
# 9              43679.0     Unsure                 Purple
# 10             62183.0     Unsure                   Blue
# 11             55068.0        3.0                   Blue
# 12             70764.0        3.0                   Blue
# 13             68196.0        3.0                 Purple
# 14             46483.0        3.0                   Blue
# 15             69059.0        4.0                 Purple
# 16             78768.0        2.0                 Purple
# 17             66948.0        3.0                   Blue
# 18             57819.0     Unsure                   Blue
# 19             54375.0        3.0                 Purple
#
#    customer_exp_preference work_env_preference personal_growth_preference  \
# 0        Strongly Disagree            Disagree                      Agree
# 1        Strongly Disagree      Strongly Agree             Strongly Agree
# 2                    Agree               Agree                      Agree
# 3                    Agree      Strongly Agree                      Agree
# 4                    Agree      Strongly Agree                      Agree
# 5                   Unsure      Strongly Agree                      Agree
# 6                    Agree      Strongly Agree                      Agree
# 7                 Disagree            Disagree                    Neutral
# 8        Strongly Disagree      Strongly Agree          Strongly Disagree
# 9           Strongly Agree      Strongly Agree                      Agree
# 10       Strongly Disagree      Strongly Agree                   Disagree
# 11                 Neutral      Strongly Agree                      Agree
# 12                   Agree            Disagree             Strongly Agree
# 13                 Neutral             Neutral                      Agree
# 14                 Neutral      Strongly Agree                      Agree
# 15                  Unsure            Disagree                   Disagree
# 16          Strongly Agree             Neutral                      Agree
# 17       Strongly Disagree   Strongly Disagree                      Agree
# 18                Disagree             Neutral                      Agree
# 19          Strongly Agree             Neutral                      Agree
#
#    honest_communication_preference community_service_preference  \
# 0                   Strongly Agree               Strongly Agree
# 1                         Disagree               Strongly Agree
# 2                          Neutral               Strongly Agree
# 3                          Neutral               Strongly Agree
# 4                          Neutral               Strongly Agree
# 5                          Neutral               Strongly Agree
# 6                Strongly Disagree               Strongly Agree
# 7                Strongly Disagree               Strongly Agree
# 8                          Neutral                      Neutral
# 9                          Neutral                        Agree
# 10                  Strongly Agree               Strongly Agree
# 11                         Neutral               Strongly Agree
# 12                         Neutral               Strongly Agree
# 13                  Strongly Agree                        Agree
# 14                           Agree               Strongly Agree
# 15               Strongly Disagree               Strongly Agree
# 16                         Neutral               Strongly Agree
# 17                           Agree               Strongly Agree
# 18                         Neutral               Strongly Agree
# 19                         Neutral               Strongly Agree
#
#    remote_work_preference industry_preference  score
# 0                  Hybrid    Renewable Energy  61.06
# 1                  Hybrid             Finance  53.20
# 2                 On-Site             Finance  70.18
# 3                  Hybrid                Tech  58.37
# 4                  Hybrid             Finance  61.77
# 5                 On-Site                Tech  69.63
# 6                  Hybrid    Higher Education  59.96
# 7                  Hybrid             Finance  52.37
# 8                  Hybrid             Finance  42.72
# 9                  Hybrid                Tech  59.85
# 10                 Remote                Tech  60.33
# 11                On-Site    Higher Education  62.61
# 12                 Hybrid    Higher Education  62.52
# 13                 Remote                Tech  70.00
# 14                On-Site             Finance  60.88
# 15                On-Site    Renewable Energy  48.43
# 16                 Remote             Finance  65.29
# 17                 Hybrid    Renewable Energy  57.35
# 18                 Hybrid             Finance  57.81
# 19                On-Site    Renewable Energy  69.36

# %% [markdown]
# ## Machine Learning and Statistical Analysis

# %% [markdown]
# ### Employees

# %%
#Preparing the dataset for linear regression...

#Assign the variables:
X = emp.drop(['score', 'wombus_id', 'birth_continent', 'gender', 'college_degree', 'total_jobs', 
             'shirt_color_preference', 'customer_exp_preference', 'work_env_preference', 'personal_growth_preference',
             'honest_communication_preference', 'community_service_preference', 'remote_work_preference', 
              'industry_preference',], axis=1)
print(X)
Y = emp.score
print(Y)
# Out:
#          age  problem_solving_skill  technology_skill  english_skill  \
# 0       51.0              14.993988         31.522899       8.274305
# 1       48.0              17.016506         24.785969       9.426865
# 2       47.0              14.993988         27.225131       5.772313
# 3       35.0              20.723280         25.528884       8.825814
# 4       45.0              15.862225         31.854325       4.140779
# ...      ...                    ...               ...            ...
# 233931  42.0              17.332522         28.914904       7.537856
# 233932  59.0              17.754821         27.755353       7.587821
# 233933  36.0              16.844175         26.380477       5.516678
# 233934  41.0              11.799902         27.049392       6.406870
# 233935  40.0              17.050439         28.585461       6.201589
#
#         most_recent_income
# 0                  65213.0
# 1                  54693.0
# 2                  47381.0
# 3                  44939.0
# 4                  57731.0
# ...                    ...
# 233931             53862.0
# 233932             52750.0
# 233933             55147.0
# 233934             68421.0
# 233935             54604.0
#
# [233936 rows x 5 columns]
# 0         61.06
# 1         53.20
# 2         70.18
# 3         58.37
# 4         61.77
#           ...
# 233931    59.15
# 233932    44.12
# 233933    65.28
# 233934    61.65
# 233935    74.77
# Name: score, Length: 233936, dtype: float64

# %%
#Importing the modules for regression models:
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
#Creating the model:

model = linear_model.LinearRegression()
model.fit(X_train, Y_train)


Y_train_pred = model.predict(X_train)

# %%
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_train, Y_train_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_train, Y_train_pred))
# Out:
# Coefficients: [ 9.17891152e-02 -3.06450302e-01 -1.99496332e-02  1.86472182e-01
#   1.52289687e-04]
# Intercept: 48.60965308500894
# Mean squared error (MSE): 58.47
# Coefficient of determination (R^2): 0.12

# %%
Y_test_pred = model.predict(X_test)

print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_test_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y_test, Y_test_pred))
# Out:
# Coefficients: [ 9.17891152e-02 -3.06450302e-01 -1.99496332e-02  1.86472182e-01
#   1.52289687e-04]
# Intercept: 48.60965308500894
# Mean squared error (MSE): 58.97
# Coefficient of determination (R^2): 0.12

# %%
#Writing the regression equation:
yintercept = '%.2f' % model.intercept_
age = '%.2f age' % model.coef_[0]
problem_solving = '%.4f problem_solving' % model.coef_[1]
technology='%.4f technology' % model.coef_[2]
english = '%.4f english' % model.coef_[3]
recent_income = '%.2f recent_income' % model.coef_[4]

# %%
#Printing the regression equation:
print('Score = ' + 
      ' ' +
      yintercept +
      ' + ' + 
      age +
      ' '  +
      problem_solving + 
      ' ' +
      technology + 
      ' + ' +
      recent_income +
      ' + ' +
      english)
# Out:
# Score =  48.61 + 0.09 age -0.3065 problem_solving -0.0199 technology + 0.00 recent_income + 0.1865 english

# %%
#Visualizations:
plt.figure(figsize=(15,7))

# 1 row, 2 column, plot 1
plt.subplot(1, 2, 1)
plt.scatter(x=Y_train, y=Y_train_pred, c="#7CAE00", alpha=0.3)

z = np.polyfit(Y_train, Y_train_pred, 1)
p = np.poly1d(z)
plt.plot(Y_test,p(Y_test),"#F8766D")

plt.ylabel('Predicted Score')
plt.xlabel('Experimental Score')

# 1 row, 2 column, plot 2
plt.subplot(1, 2, 2)
plt.scatter(x=Y_test, y=Y_test_pred, c="#619CFF", alpha=0.3)

z = np.polyfit(Y_test, Y_test_pred, 1)
p = np.poly1d(z)
plt.plot(Y_test,p(Y_test),"#F8766D")

plt.xlabel('Experimental Score')

plt.savefig('emp_score_plot.png')
plt.show()

# %% [markdown]
# ### Recruits/Candidates:

# %%
#Creating a score variable for the candidates:

rec['age'].apply(lambda x: float(x))
rec['problem_solving_skill'].apply(lambda x: float(x))
rec['english_skill'].apply(lambda x: float(x))
rec['technology_skill'].apply(lambda x: float(x))

cal_age = 0.09*(rec['age'])
cal_solve = 0.3065*(rec['problem_solving_skill'])
cal_eng = 0.1865*(rec['english_skill'])
cal_tech = 0.0199*(rec['technology_skill'])

#Compute, assign, and print the score:
cal_score = 48.61 + cal_age - cal_solve - cal_tech + cal_eng
rec = rec.assign(score = cal_score)

# %% [markdown]
# ## New Datasets

# %%
#Exporting the manipulated datasets:
rec.to_csv(r'../resources/recruits.csv')
emp.to_csv(r'../resources/employees.csv')

# %%
#Choosing the top 100 candidates based on score:
sorted_rec = rec.sort_values(['score'], ascending = [False])
print(sorted_rec)
# Out:
#      wombus_id birth_continent  gender   age college_degree  \
# 78        1183   North America  Female  60.0            0.0
# 105       1210   North America    Male  64.0            1.0
# 72        1177   North America  Female  52.0            0.0
# 124       1229   North America    Male  69.0            1.0
# 287       1392            Asia  Female  51.0            0.0
# ..         ...             ...     ...   ...            ...
# 106       1211            Asia  Female  36.0            0.0
# 22        1127            Asia  Female  27.0            0.0
# 408       1513   North America  Female  23.0            1.0
# 226       1331   North America    Male  36.0            0.0
# 21        1126            Asia  Female  32.0            1.0
#
#      problem_solving_skill  technology_skill  english_skill  \
# 78                4.432909         23.911012       9.366827
# 105               7.445124         19.730772       9.675103
# 72                5.113707         19.150908       8.142138
# 124              10.982391         21.191386       9.194934
# 287               5.510994         19.165763       6.944867
# ..                     ...               ...            ...
# 106              21.949605         29.830484       5.202859
# 22               22.260432         27.019320       8.142138
# 408              21.283289         26.025619       7.914534
# 226              26.553890         28.856255       8.934073
# 21               24.568069         29.614281       6.236458
#
#      most_recent_income total_jobs shirt_color_preference  \
# 78              87808.0     Unsure                   Blue
# 105             79881.0     Unsure                 Purple
# 72              86017.0        5.0                   Blue
# 124             70573.0        6.0                 Purple
# 287             84971.0     Unsure                 Purple
# ..                  ...        ...                    ...
# 106             41712.0        3.0                   Blue
# 22              40894.0        4.0                 Purple
# 408             43465.0        4.0                 Purple
# 226             29595.0        3.0                 Purple
# 21              34821.0     Unsure                   Blue
#
#     customer_exp_preference work_env_preference personal_growth_preference  \
# 78        Strongly Disagree             Neutral                   Disagree
# 105                   Agree      Strongly Agree                    Neutral
# 72                  Neutral            Disagree                   Disagree
# 124                   Agree   Strongly Disagree                      Agree
# 287                Disagree      Strongly Agree                      Agree
# ..                      ...                 ...                        ...
# 106          Strongly Agree             Neutral                      Agree
# 22           Strongly Agree             Neutral             Strongly Agree
# 408                 Neutral             Neutral                   Disagree
# 226                   Agree      Strongly Agree                      Agree
# 21                    Agree      Strongly Agree                      Agree
#
#     honest_communication_preference community_service_preference  \
# 78                          Neutral               Strongly Agree
# 105                  Strongly Agree                     Disagree
# 72                          Neutral               Strongly Agree
# 124                           Agree               Strongly Agree
# 287                         Neutral               Strongly Agree
# ..                              ...                          ...
# 106                         Neutral                        Agree
# 22                          Neutral                        Agree
# 408                         Neutral               Strongly Agree
# 226               Strongly Disagree                        Agree
# 21                          Neutral               Strongly Agree
#
#     remote_work_preference industry_preference      score
# 78                  Hybrid             Finance  53.922397
# 105                 Hybrid                Tech  53.499834
# 72                  Remote    Renewable Energy  52.860055
# 124                 Hybrid                Tech  52.747044
# 287                 Remote                Tech  52.424699
# ..                     ...                 ...        ...
# 106                 Hybrid                Tech  45.499153
# 22                  Hybrid                Tech  45.198002
# 408                 Remote    Renewable Energy  45.114823
# 226                 Hybrid    Higher Education  44.803198
# 21                  Hybrid    Renewable Energy  44.533662
#
# [449 rows x 19 columns]

# %%
#Checking that the data was sorted correctly:
rec['score'].describe()
# Out:
# count    449.000000
# mean      49.094013
# std        1.585543
# min       44.533662
# 25%       48.171060
# 50%       49.104692
# 75%       50.100144
# max       53.922397
# Name: score, dtype: float64

# %%
#Highlighting the top 100 candidates and exporting them to a new dataframe:
top100 = sorted_rec.head(100)
top100.to_csv(r'../resources/top100.csv')

# %%
#Visualize the (predicted/calculated) candidate scores:
plt.figure(figsize=(15,7))

# 1 row, 2 column, plot 1
plt.subplot(1, 2, 1)
plt.hist(rec['score'], bins = 15, color = 'blue', edgecolor= 'black')
plt.ylabel('Volume of Candidates')
plt.xlabel('Score')
plt.title('All Candidates')

# 1 row, 2 column, plot 2
plt.subplot(1, 2, 2)
plt.hist(top100['score'], bins = 5, color = 'green', edgecolor= 'black')
plt.xlabel('Score')
plt.title('Top 100 Candidates')
# Out:
# Text(0.5, 1.0, 'Top 100 Candidates')

# %% [markdown]
# ## Establishing Top Candidates via SQL

# %%
#Establish a connection to SQL: 
from sqlalchemy import create_engine

# Creating connection object
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5432
database_name = 'postgres'

# %%
#Create engine connection:
connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'

engine = create_engine(connection_string)

# %%
rec.to_sql(name='candidates', con=engine, if_exists='replace', index=False)
engine.execute("SELECT wombus_id, gender, score FROM candidates ORDER BY score DESC LIMIT 100").fetchall()
# Out:
# [(1183, 'Female', 53.9223974166005),
#  (1210, 'Male', 53.4998337070155),
#  (1177, 'Female', 52.860054628769504),
#  (1229, 'Male', 52.7470439499155),
#  (1392, 'Female', 52.42469938124351),
#  (1340, 'Male', 52.3937718938865),
#  (1454, 'Male', 52.2373870258185),
#  (1153, 'Male', 52.1760215561455),
#  (1106, 'Female', 52.105834211197504),
#  (1326, 'Female', 52.0466140224726),
#  (1363, 'Female', 52.04654339932),
#  (1550, 'Male', 52.0366875130645),
#  (1401, 'Female', 52.019200590825),
#  (1228, 'Female', 51.9742888541103),
#  (1428, 'Male', 51.9091468729925),
#  (1438, 'Female', 51.8962501517055),
#  (1538, 'Female', 51.8750933561495),
#  (1305, 'Female', 51.868668654105),
#  (1529, 'Female', 51.8685458876615),
#  (1147, 'Female', 51.8487524571795),
#  (1234, 'Female', 51.82092935795551),
#  (1317, 'Female', 51.698028256002004),
#  (1415, 'Female', 51.69662291201401),
#  (1315, 'Male', 51.653883081751495),
#  (1541, 'Male', 51.63665161059699),
#  (1243, 'Male', 51.619330000407494),
#  (1444, 'Male', 51.615710590832),
#  (1207, 'Female', 51.54756008731899),
#  (1462, 'Female', 51.546951913354),
#  (1533, 'Female', 51.51825264366201),
#  (1418, 'Female', 51.51358713311901),
#  (1309, 'Male', 51.480565681453996),
#  (1337, 'Male', 51.475274158392494),
#  (1176, 'Male', 51.447844526678),
#  (1440, 'Female', 51.436268060284995),
#  (1359, 'Female', 51.413052970805),
#  (1461, 'Male', 51.409328407358),
#  (1398, 'Female', 51.387513258701),
#  (1195, 'Female', 51.3801781878025),
#  (1410, 'Female', 51.36231452013199),
#  (1430, 'Male', 51.36023466431249),
#  (1275, 'Female', 51.325735940519),
#  (1188, 'Male', 51.3085644895375),
#  (1217, 'Male', 51.2991901111045),
#  (1375, 'Male', 51.27069730231349),
#  (1213, 'Female', 51.241991449831),
#  (1105, 'Female', 51.2288097439255),
#  (1277, 'Male', 51.202802096819),
#  (1511, 'Female', 51.20039177023),
#  (1522, 'Male', 51.185182697024004),
#  (1284, 'Female', 51.125022918991),
#  (1474, 'Male', 51.112384693356994),
#  (1382, 'Male', 51.100821934228506),
#  (1439, 'Male', 51.043629949039506),
#  (1553, 'Male', 51.0258005230485),
#  (1294, 'Male', 51.004220169399),
#  (1230, 'Female', 50.995871562951),
#  (1160, 'Male', 50.968361877372494),
#  (1335, 'Male', 50.9652886663326),
#  (1498, 'Female', 50.915919656541),
#  (1264, 'Male', 50.873699739066),
#  (1478, 'Male', 50.8633641129635),
#  (1503, 'Male', 50.843747242956994),
#  (1380, 'Female', 50.8433873285585),
#  (1215, 'Female', 50.791633382728506),
#  (1339, 'Male', 50.7905547061335),
#  (1464, 'Female', 50.748306042288),
#  (1417, 'Female', 50.733748384357995),
#  (1165, 'Male', 50.7254561326615),
#  (1174, 'Female', 50.72022011697351),
#  (1507, 'Female', 50.69389442306699),
#  (1237, 'Female', 50.693735915233496),
#  (1367, 'Male', 50.6900775513855),
#  (1406, 'Male', 50.6775023441295),
#  (1341, 'Male', 50.660587574873),
#  (1372, 'Male', 50.6575396164875),
#  (1545, 'Male', 50.617919342361),
#  (1472, 'Female', 50.608026350096),
#  (1310, 'Female', 50.5821610613245),
#  (1281, 'Female', 50.5433869463975),
#  (1163, 'Male', 50.53155911764951),
#  (1128, 'Male', 50.500377917416),
#  (1456, 'Male', 50.49280580942949),
#  (1212, 'Female', 50.4815058422915),
#  (1319, 'Male', 50.4780961393935),
#  (1535, 'Female', 50.436991342547),
#  (1436, 'Female', 50.427568716421504),
#  (1208, 'Female', 50.412552086046),
#  (1509, 'Male', 50.409111776402995),
#  (1172, 'Female', 50.4052282626725),
#  (1115, 'Female', 50.363119577804),
#  (1156, 'Male', 50.33246308238301),
#  (1271, 'Male', 50.3289009543355),
#  (1411, 'Female', 50.31954486719851),
#  (1185, 'Male', 50.290000429562994),
#  (1291, 'Female', 50.2895630547535),
#  (1302, 'Female', 50.2873779337565),
#  (1336, 'Female', 50.275527326630005),
#  (1395, 'Male', 50.274422845648),
#  (1152, 'Male', 50.263988690668505)]
